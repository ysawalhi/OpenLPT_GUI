# %%
import numpy as np 
import matplotlib.pyplot as plt
import io, pyopenlpt as lpt

redirector = lpt.PythonStreamRedirector()

import pybind11
from IPython.core.magic import register_cell_magic

@register_cell_magic
def skip(line, cell):
    print("⏭️ skipped this cell")
    # 什么都不执行，直接返回
    return

# %%
# %%skip # skip this cell (comment this out if you want to run this cell)
# # test bubble basic functions
# import numpy as np
# from scipy.io import loadmat
#
# # read camera information
# config_file = '../../test/inputs/test_STB_Bubble/config_python.txt'
# basic_settings = lpt.BasicSetting()
# basic_settings.readConfig(config_file)
# cam_list = basic_settings._cam_list
#
# # load synthetic data
# data   = loadmat('../../test/inputs/test_STB_Bubble/data.mat')
# tracks = data['tracks']
# r_mm   = data['r_mm']           # shape: (N, 2) -> [id, radius_mm]
# img_bb_ref = data['b_ref']
#
# # --- robust ID→radius lookup (avoid float==float pitfalls) ---
# ids = r_mm[:, 0].astype(int)
# rs  = r_mm[:, 1].astype(float)
# id_to_r = dict(zip(ids, rs))
#
# bb1    = tracks[0, :3]
# id_bb1 = int(round(tracks[0, 4]))     # ensure integer id
# r_bb1  = float(id_to_r[id_bb1])       # scalar, no DeprecationWarning
#
# # build object (scalar radius!)
# obj_bb1 = lpt.Bubble3D(lpt.Pt3D(float(bb1[0]), float(bb1[1]), float(bb1[2])), r_bb1)
# print(obj_bb1._pt_center, obj_bb1._r3d)
#
# # 2D radius
# with lpt.PythonStreamRedirector():
#     obj_bb1.projectObject2D(cam_list)
#
# r_bb1_check = lpt.Bubble.calRadiusFromOneCam(cam_list[0], obj_bb1._pt_center, obj_bb1._obj2d_list[0]._r_px)
# r_bb1_check2 = lpt.Bubble.calRadiusFromCams(cam_list, obj_bb1._pt_center, obj_bb1._obj2d_list)
# print(r_bb1, r_bb1_check, r_bb1_check2)
#
# lptimg_bb_ref = lpt.Image.from_numpy(img_bb_ref.astype(np.uint8))
# d_b = max(1, int(round(float(obj_bb1._obj2d_list[0]._r_px) * 2.0)))
# resizer = lpt.BubbleResize()
# img1_bb1 = resizer.ResizeBubble(lptimg_bb_ref, d_b, cam_list[0]._max_intensity)
#
# arr = np.array(img1_bb1.to_list(), dtype=np.uint8)
#
# # 画出来
# plt.imshow(arr, cmap="gray", origin="upper")
# plt.colorbar()
# plt.title("Resized Bubble")
# plt.show()
# Out:
# ⏭️ skipped this cell

# %%
# %%skip # skip this cell (comment this out if you want to run this cell)
#
# # generate bubble synthetic image
# # Generate synthetic bubble images (occlusion compositing)
# # Inputs: tracks [x,y,z, frame_id, track_id], r_mm [track_id, radius_mm], img_bb_ref (template)
# # Outputs:
# #   ../../test/inputs/test_STB_Bubble/imgFile/cam{1..4}/img00000.tif
# #   ../../test/inputs/test_STB_Bubble/imgFile/cam{1..4}ImageNames_python.txt
#
# import os
# import math
# import numpy as np
# from scipy.io import loadmat
# from tifffile import imwrite
#
# # ========= 路径 =========
# ROOT = '../../test/inputs/test_STB_Bubble'
# OUT_ROOT = os.path.join(ROOT, 'imgFile')
# os.makedirs(OUT_ROOT, exist_ok=True)
#
# # ========= 相机（均为 PINHOLE 且 active）=========
# basic_settings = lpt.BasicSetting()
# basic_settings.readConfig(os.path.join(ROOT, 'config_python.txt'))
# cam_list = basic_settings._cam_list
# n_cam = len(cam_list)
# assert n_cam >= 1, "No camera found."
#
# # ========= 数据 =========
# data = loadmat(os.path.join(ROOT, 'data.mat'))
# tracks = data['tracks']          # [x,y,z, frame_id, track_id]
# r_mm   = data['r_mm']            # [track_id, radius_mm]
# img_bb_ref_np = data['b_ref']    # 模板 (2D)
#
# # TrackID -> 半径(mm)
# ids = r_mm[:, 0].astype(int)
# rs  = r_mm[:, 1].astype(float)
# id_to_r = dict(zip(ids, rs))
#
# # 模板转 lpt.Image
# lptimg_bb_ref = lpt.Image.from_numpy(img_bb_ref_np.astype(np.uint8))
#
# # ========= 工具 =========
# def frame_to_name(fid: int) -> str:
#     return f"img{int(fid):05d}.tif"
#
# def ensure_cam_dirs(out_root: str, n_cam: int):
#     ds = []
#     for i in range(n_cam):
#         d = os.path.join(out_root, f"cam{i+1}")
#         os.makedirs(d, exist_ok=True)
#         ds.append(d)
#     return ds
#
# def proj_ok(o2d) -> bool:
#     u = o2d._pt_center[0]
#     v = o2d._pt_center[1]
#     return np.isfinite(u) and np.isfinite(v)
#
# def valid_r(r_px) -> bool:
#     return np.isfinite(r_px) and (r_px > 0.25)
#
# def get_RT_for_cam(cam):
#     """Xc = R*Xw + T（PINHOLE）；从 pinhole_param 取 r_mtx/t_vec"""
#     p = cam._pinhole_param
#     R = np.array(p.r_mtx.to_list(), dtype=float).reshape(3, 3)
#     T = np.array(p.t_vec.to_list(),  dtype=float).reshape(3)
#     return R, T
#
# def cam_depth_Zc(cam, Xw_xyz):
#     """返回 Zc；系统朝 +Z 看 → Zc 越大越远"""
#     R, T = get_RT_for_cam(cam)
#     Xw = np.array(Xw_xyz, dtype=float)
#     Xc = R @ Xw + T
#     return float(Xc[2])
#
# def paste_cover_masked(canvas: np.ndarray, patch: np.ndarray, mask: np.ndarray, cx: int, cy: int):
#     """
#     遮挡合成：只在 mask=True 且 patch>0 的位置覆盖；自动裁剪越界
#     canvas/patch: uint8, HxW
#     """
#     H, W = canvas.shape
#     ph, pw = patch.shape
#     x0 = cx - pw // 2; y0 = cy - ph // 2
#     x1 = x0 + pw;      y1 = y0 + ph
#
#     sx0 = max(0, x0); sy0 = max(0, y0)
#     sx1 = min(W, x1); sy1 = min(H, y1)
#     if sx0 >= sx1 or sy0 >= sy1:
#         return
#
#     px0 = sx0 - x0; py0 = sy0 - y0
#     px1 = px0 + (sx1 - sx0); py1 = py0 + (sy1 - sy0)
#
#     pr  = patch[py0:py1, px0:px1]
#     mr  = mask [py0:py1, px0:px1]
#     cr  = canvas[sy0:sy1, sx0:sx1]
#
#     use = mr & (pr > 0)
#     cr[use] = pr[use]
#
# # 圆形掩膜缓存
# mask_cache = {}
# def get_circular_mask(d_b: int, patch_np: np.ndarray) -> np.ndarray:
#     """
#     生成与 patch 同尺寸的布尔圆掩膜（半径 ~ d_b/2），裁掉方形角落
#     """
#     key = (int(d_b), tuple(patch_np.shape))
#     m = mask_cache.get(key)
#     if m is None:
#         ph, pw = patch_np.shape
#         r = 0.5 * min(int(d_b), ph, pw)
#         cy = (ph - 1) / 2.0
#         cx = (pw - 1) / 2.0
#         yy, xx = np.ogrid[:ph, :pw]
#         m = ((xx - cx) ** 2 + (yy - cy) ** 2) <= (r * r)
#         mask_cache[key] = m
#     return m
#
# # ========= 输出 =========
# cam_dirs  = ensure_cam_dirs(OUT_ROOT, n_cam)
# cam_lists = [[] for _ in range(n_cam)]
#
# img_sizes  = [(cam.getNRow(), cam.getNCol()) for cam in cam_list]
# max_intens = [float(cam._max_intensity) for cam in cam_list]
#
# resizer = lpt.BubbleResize()
# # 不同相机（幅值）与直径的补丁缓存
# patch_cache = {}  # key: (icam, diameter_px) -> np.uint8 patch
#
# all_frames = np.unique(tracks[:, 3].astype(int))
# print(f"Total frames: {len(all_frames)}, cameras: {n_cam}")
#
# # ========= 主循环 =========
# for fi, fid in enumerate(all_frames):
#     # 每相机一张空画布
#     canvases = [np.zeros(sz, dtype=np.uint8) for sz in img_sizes]
#     rows_f = tracks[tracks[:, 3].astype(int) == int(fid), :]
#
#     # 为每个相机收集绘制项：(Zc, u, v, patch_np, mask_np)
#     drawlists = [[] for _ in range(n_cam)]
#
#     if rows_f.size > 0:
#         for row in rows_f:
#             x = float(row[0]); y = float(row[1]); z = float(row[2])
#             tid = int(round(row[4]))
#             R3D = float(id_to_r.get(tid, 0.0))
#             if not (R3D > 0.0 and math.isfinite(R3D)):
#                 continue
#
#             obj = lpt.Bubble3D(lpt.Pt3D(x, y, z), R3D)
#             with lpt.PythonStreamRedirector():
#                 obj.projectObject2D(cam_list)
#
#             for icam, cam in enumerate(cam_list):
#                 o2d = obj._obj2d_list[icam]
#                 if not proj_ok(o2d):
#                     continue
#                 r_px = float(o2d._r_px)
#                 if not valid_r(r_px):
#                     continue
#
#                 u = int(round(o2d._pt_center[0]))
#                 v = int(round(o2d._pt_center[1]))
#                 d_b = max(1, int(round(2.0 * r_px)))  # 直径（像素）
#
#                 key = (icam, d_b)
#                 if key not in patch_cache:
#                     patch_img = resizer.ResizeBubble(lptimg_bb_ref, d_b, max_intens[icam])
#                     patch_np  = np.array(patch_img.to_list(), dtype=np.uint8)
#                     patch_cache[key] = patch_np
#                 else:
#                     patch_np = patch_cache[key]
#
#                 mask_np = get_circular_mask(d_b, patch_np)
#                 Zc = cam_depth_Zc(cam, (x, y, z))
#                 if not np.isfinite(Zc):
#                     continue
#
#                 drawlists[icam].append((Zc, u, v, patch_np, mask_np))
#
#     # 画家算法：相机朝 +Z → Zc 从大到小（先远后近）
#     for icam in range(n_cam):
#         for Zc, u, v, patch_np, mask_np in sorted(drawlists[icam], key=lambda t: t[0], reverse=True):
#             paste_cover_masked(canvases[icam], patch_np, mask_np, u, v)
#
#         fname = frame_to_name(fid)
#         save_path = os.path.join(cam_dirs[icam], fname)
#         imwrite(save_path, canvases[icam])
#
#         # 清单写相对路径（与你示例一致）
#         rel_path = os.path.join(OUT_ROOT, f"cam{icam+1}", fname)
#         cam_lists[icam].append(rel_path)
#
#     if (fi + 1) % 10 == 0 or fi == 0:
#         print(f"[{fi+1}/{len(all_frames)}] frame {fid} done (occlusion, circular mask).")
#
# # ========= 写清单 =========
# for icam in range(n_cam):
#     list_txt = os.path.join(OUT_ROOT, f"cam{icam+1}ImageNames_python.txt")
#     with open(list_txt, 'w', encoding='utf-8') as f:
#         for p in cam_lists[icam]:
#             f.write(p.replace("\\", "/") + "\n")
#     print(f"Wrote {list_txt} ({len(cam_lists[icam])} lines)")
# Out:
# ⏭️ skipped this cell

# %%
config_file = '../../test/inputs/test_STB_Bubble/config_python.txt'
basic_settings = lpt.BasicSetting()
basic_settings.readConfig(config_file)
cam_list = basic_settings._cam_list

from pprint import pprint

with lpt.PythonStreamRedirector():
    bb_cfg = lpt.BubbleConfig()
    bb_cfg.readConfig(basic_settings._object_config_paths[0], basic_settings)

# 子结构字段白名单
SUBFIELDS = {
    "IPRParam": [
        "n_cam_reduced", "n_loop_ipr", "n_loop_ipr_reduced", "n_obj2d_process_max"
    ],
    "PFParam": [
        "limit", "nx", "ny", "nz", "r",
        "nBin_x", "nBin_y", "nBin_z",
        "is_smooth", "sigma_x", "sigma_y", "sigma_z"
    ],
    "SMParam": [
        "match_cam_count", "idmap_cell_px", "tol_2d_px", "tol_3d_mm"
    ],
    "ShakeParam": [
        "_shake_width", "_n_shake_loop", "_thred_ghost", "_shakewidth_min", "_ratio_augimg"
    ],
    "STBParam": [
        "_radius_search_obj", "_n_initial_frames", "_radius_search_track"
    ],
}

# Config（派生 + 基类）的候选字段（存在就取）
CONFIG_CANDIDATES = [
    # BUbbleConfig 自身
    "_radius_min", "_radius_max", "_sense", "_bb_ref_img",
    # ObjectConfig 基类
    "_n_thread", "_stb_param", "_shake_param", "_pf_param", "_ipr_param", "_sm_param",
]

def _maybe_extract(obj):
    """递归展开已知的子结构；否则返回原值或字符串"""
    tname = type(obj).__name__
    if tname in SUBFIELDS:
        out = {}
        for name in SUBFIELDS[tname]:
            out[name] = getattr(obj, name)
        return out
    return obj  # 对未列白名单的类型（如 OTF）直接返回对象本身

def bubble_cfg_to_dict(bb_cfg):
    d = {}
    # 合并派生类 + 基类字段（存在就读）
    for name in CONFIG_CANDIDATES:
        if hasattr(bb_cfg, name):
            val = getattr(bb_cfg, name)
            d[name] = _maybe_extract(val)
    # kind 是只读属性
    d["kind"] = bb_cfg.kind
    return d

# 用法
pprint(bubble_cfg_to_dict(bb_cfg), sort_dicts=False, width=100)
# Out:
# {'_radius_min': 2,
#  '_radius_max': 30,
#  '_sense': 0.9,
#  '_bb_ref_img': <pyopenlpt.BubbleRefImg object at 0x00000234AED6BDB0>,
#  '_stb_param': {'_radius_search_obj': 0.4, '_n_initial_frames': 4, '_radius_search_track': 1.2},
#  '_shake_param': {'_shake_width': 0.02,
#                   '_n_shake_loop': 4,
#                   '_thred_ghost': 0.1,
#                   '_shakewidth_min': 0.001,
#                   '_ratio_augimg': 2},
#  '_pf_param': {'limit': <pyopenlpt.AxisLimit object at 0x00000234B244CE30>,
#                'nx': 51,
#                'ny': 51,
#                'nz': 51,
#                'r': 1.0,
#                'nBin_x': 11,
#                'nBin_y': 11,
#                'nBin_z': 11,
#                'is_smooth': True,
#                'sigma_x': 1.0,
#                'sigma_y': 1.0,
#                'sigma_z': 1.0},
#  '_ipr_param': {'n_cam_reduced': 1,
#                 'n_loop_ipr': 2,
#                 'n_loop_ipr_reduced': 1,
#                 'n_obj2d_process_max': 200000},
#  '_sm_param': {'match_cam_count': 3, 'idmap_cell_px': 4, 'tol_2d_px': 2.0, 'tol_3d_mm': 0.08},
#  'kind': <ObjectKind.Bubble: 1>}

# %%
# create ImageIO instances for each image path
imgio_list = []
for path in basic_settings._image_file_paths:
    io = lpt.ImageIO()
    io.loadImgPath("", path)
    imgio_list.append(io)

num_cams = len(imgio_list)
frame_id = 0

image_list = []
for i in range(num_cams):
    image_list.append(imgio_list[i].loadImg(frame_id))

arr = np.array(image_list[0].to_list(), dtype=np.uint8)

plt.imshow(arr, cmap="gray")
plt.show()

# %%
obj_finder = lpt.ObjectFinder2D()
n_cams = len(cam_list)
obj2d_list = []
for cam_id in range(n_cams):
    obj2ds = obj_finder.findObject2D(image_list[cam_id], bb_cfg)
    obj2d_list.append(obj2ds)
    print(f"Camera {cam_id}: found {len(obj2ds)} objects.")

from matplotlib.patches import Circle
from matplotlib.collections import PatchCollection

img = np.array(image_list[1].to_list(), dtype=np.uint8)
points = obj2d_list[1]

xs = [float(p._pt_center[0]) for p in points]
ys = [float(p._pt_center[1]) for p in points]
rs = [float(p._r_px)        for p in points] 

h, w = img.shape[:2]
dpi = 200
figsize = (w / dpi, h / dpi)

fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
ax.imshow(img, cmap="gray", interpolation="none", origin="upper")

# 用 PatchCollection 一次性添加很多圆，效率更高
circles = [Circle((x, y), r) for x, y, r in zip(xs, ys, rs)]
pc = PatchCollection(
    circles,
    facecolor='none',       # 空心
    edgecolor='r',
    linewidths=0.5,
    antialiased=True
)
ax.add_collection(pc)

ax.set_title("Camera 2 detections")
ax.axis("off")
plt.show()

# test whether there are repeated points
# ---- 参数 ----
cam_id = 0
px_thresh = 2.0  # 判定重复的像素距离阈值

# ---- 取出该相机的图像与检测点 ----
img = np.array(image_list[cam_id].to_list(), dtype=np.uint8)
points = obj2d_list[cam_id]

xs = np.array([float(p._pt_center[0]) for p in points], dtype=float)
ys = np.array([float(p._pt_center[1]) for p in points], dtype=float)
rs = np.array([float(p._r_px)        for p in points], dtype=float)
centers = np.column_stack([xs, ys])
n = len(points)

# ---- 找到疑似重复点索引（任意邻居在阈值内即视为重复）----
dup_mask = np.zeros(n, dtype=bool)

try:
    # 优先使用 SciPy 加速（若可用）
    from scipy.spatial import cKDTree
    tree = cKDTree(centers)
    # 与自身比较，半径搜索；返回每个点的邻居索引列表
    neighs = tree.query_ball_tree(tree, r=px_thresh)
    for i, lst in enumerate(neighs):
        # 列表通常包含自身 i；只要存在别的 j ≠ i 即标记为重复
        if any(j != i for j in lst):
            dup_mask[i] = True
except Exception:
    # 纯 numpy 方案（O(N^2)），小样本足够快
    diff = centers[:, None, :] - centers[None, :, :]      # [n, n, 2]
    dist2 = np.sum(diff * diff, axis=-1)                  # [n, n]
    np.fill_diagonal(dist2, np.inf)                       # 排除自身
    dup_mask = (dist2 <= px_thresh * px_thresh).any(axis=1)

n_dup = int(dup_mask.sum())
print(f"Camera {cam_id}: {n} objects, suspected duplicates within {px_thresh}px = {n_dup}")

# （可选）打印前几个重复对以便人工核查
if n_dup > 0:
    # 简单找一些代表性配对
    shown = 0
    for i in np.where(dup_mask)[0]:
        # 找距离最近的一个邻居
        d2 = (centers - centers[i])**2
        d = np.sqrt(d2.sum(axis=1))
        d[i] = np.inf
        j = int(np.argmin(d))
        if d[j] <= px_thresh:
            print(f"  pair: ({i}, {j}) dist={d[j]:.3f}px  centers=({xs[i]:.1f},{ys[i]:.1f}) & ({xs[j]:.1f},{ys[j]:.1f})")
            shown += 1
        if shown >= 10:
            break

# ---- 绘图：普通点=红色，重复点=青色 ----
h, w = img.shape[:2]
dpi = 200
figsize = (w / dpi, h / dpi)

fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
ax.imshow(img, cmap="gray", interpolation="none", origin="upper")

# # 先画普通点
# circles_norm = [Circle((x, y), r) for x, y, r in zip(xs[~dup_mask], ys[~dup_mask], rs[~dup_mask])]
# pc_norm = PatchCollection(circles_norm, facecolor='none', edgecolor='r', linewidths=0.5, antialiased=True)
# ax.add_collection(pc_norm)

# 再画疑似重复点
circles_dup = [Circle((x, y), r) for x, y, r in zip(xs[dup_mask], ys[dup_mask], rs[dup_mask])]
pc_dup = PatchCollection(circles_dup, facecolor='none', edgecolor='c', linewidths=0.8, antialiased=True)
ax.add_collection(pc_dup)

ax.set_title(f"Camera {cam_id} detections (dup in {px_thresh}px = cyan)")
ax.axis("off")
plt.show()
# Out:
# Camera 0: found 839 objects.
# Camera 1: found 843 objects.
# Camera 2: found 794 objects.
# Camera 3: found 805 objects.
# Camera 0: 839 objects, suspected duplicates within 2.0px = 0

# %%
# test stereo matching
# to obtain bubble reference image, match camera number must equal to total camera number
bb_cfg._sm_param.match_cam_count = len(cam_list)
stereomath = lpt.StereoMatch(cam_list, obj2d_list, bb_cfg)
obj3d_list = stereomath.match()
print(f"Matched {len(obj3d_list)} 3D objects.")

# only match_cam_count cams have valid 2D projections
n_check = min(10, len(obj3d_list))

# for i, obj in enumerate(obj3d_list[:n_check]):
#     valid_cams = [c for c, o2d in enumerate(obj._obj2d_list) if o2d is not None]
#     n_valid = len(valid_cams)
#     print(f"obj#{i}: total cams={len(obj._obj2d_list)}, valid 2D={n_valid}, cams={valid_cams}")

# obtain bubble reference image
get_bb_img = bb_cfg._bb_ref_img.calBubbleRefImg(obj3d_list, obj2d_list, cam_list, image_list)
print(get_bb_img)

arr = np.array(bb_cfg._bb_ref_img[2].to_list(), dtype=np.uint8)
print(arr.shape)

# 画出来
plt.imshow(arr, cmap="gray", origin="upper", vmin=0, vmax=255)
plt.colorbar()
plt.title("Bubble Reference Image")
plt.show()

from scipy.io import loadmat
import sys, pathlib
repo_root = pathlib.Path.cwd().parent          # for finding openLPT_utils
sys.path.insert(0, str(repo_root))
from openLPT_utils.ghost_eval import find_ghosts
# to check the quality of matched bubbles
data   = loadmat('../../test/inputs/test_STB_Bubble/data.mat')
tracks = data['tracks']
r_mm   = data['r_mm']           # shape: (N, 2) -> [id, radius_mm]

mask = tracks[:, 3] == 1  # get the first frame
pts_groundtrue = tracks[mask, :3].astype(np.float32)
ids_groundtrue = tracks[mask, 4].astype(int)
# 建立 id -> 半径 的映射
id2r = {int(i): float(r) for i, r in r_mm}
# 逐个取半径
r_groundtrue = np.array([id2r[i] for i in ids_groundtrue], dtype=np.float32)

print(f"number of objects in GT: {len(pts_groundtrue)}, reconstructed: {len(obj3d_list)}")
pts_reconstructed = np.array(
    [[obj._pt_center[0], obj._pt_center[1], obj._pt_center[2]] for obj in obj3d_list], 
    dtype=np.float32)

tol_mm = 2 * .04
cmp_st = find_ghosts(pts_groundtrue, pts_reconstructed, tol_mm, use_ckdtree=True)

print(f"real={len(cmp_st['matched_indices'])}, ghosts={len(cmp_st['ghost_indices'])}")
from matplotlib.ticker import FormatStrFormatter, MaxNLocator

d = np.asarray(cmp_st['dist_mm'], float)
d = d[np.isfinite(d)]
if d.size == 0:
    print("dist_mm 为空")
else:
    p99 = np.percentile(d, 99)           # 只看前 99%，避免长尾挤压
    xmin, xmax = 0.0, p99
    bin_count = 50                       # 想更平滑就调大/调小

    fig, ax = plt.subplots(figsize=(6, 3), dpi=150)
    ax.hist(d, bins=bin_count, range=(xmin, xmax), density=False, alpha=0.85)
    if 'tol_mm' in globals():
        ax.axvline(float(tol_mm), ls='--')
    ax.set_xlim(xmin, xmax)
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))  # 一位小数
    ax.xaxis.set_major_locator(MaxNLocator(nbins=6))          # 控制刻度数量
    ax.set_xlabel('distance (mm)')
    ax.set_ylabel('count')
    ax.set_title('dist_mm histogram')
    plt.tight_layout(); plt.show()

from matplotlib.patches import Circle
import matplotlib.cm as cm

def show_ghosts_on_4cams(image_list, obj3d_list, ghost_indices, cam_ids=(0,1,2,3)):
    """在多相机图上圈出 ghost 对象，每个 ghost 用不同颜色。"""
    n_ghosts = len(ghost_indices)
    cmap = cm.get_cmap('rainbow', n_ghosts)   # 从 tab20 colormap 取 n_ghosts 种颜色

    # ---- 画图 ----
    fig, axs = plt.subplots(2, 2, figsize=(10, 6), dpi=150)
    axs = axs.ravel()
    for ax, cam in zip(axs, cam_ids):
        img = np.array(image_list[cam].to_list(), dtype=np.uint8)
        ax.imshow(img, cmap="gray", interpolation="none", origin="upper")

        # 遍历每个 ghost
        for gi, idx in enumerate(ghost_indices):
            try:
                o2d = obj3d_list[idx]._obj2d_list[cam]
                x, y = float(o2d._pt_center[0]), float(o2d._pt_center[1])
                r = float(getattr(o2d, "_r_px", 3.0))
                if np.isfinite(x) and np.isfinite(y) and r > 0:
                    color = cmap(gi)  # 该 ghost 的唯一颜色
                    circ = Circle((x, y), r, fill=False, edgecolor=color, linewidth=1.0)
                    ax.add_patch(circ)
                    # ax.plot(x, y, '.', color=color, ms=5)
            except Exception:
                # 该相机上可能没有该 ghost 的2D投影
                pass

        ax.set_title(f"Camera {cam}")
        ax.axis("off")

    fig.tight_layout()
    plt.show()

show_ghosts_on_4cams(image_list, obj3d_list, cmp_st['ghost_indices'], cam_ids=(0,1,2,3))
# Out:
# Matched 401 3D objects.
# True
# (34, 34)
# number of objects in GT: 1000, reconstructed: 401
# real=398, ghosts=3
# C:\Users\tan_s\AppData\Local\Temp\ipykernel_34848\2154397068.py:85: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('rainbow', n_ghosts)   # 从 tab20 colormap 取 n_ghosts 种颜色

# %%
shaker = lpt.Shake(cam_list, bb_cfg)
print(shaker.cams[0]._type)

flags, obj3d_list_shaked = shaker.runShake(obj3d_list, image_list)
arr = np.asarray([int(f) for f in flags])  
n_ghost    = int(np.count_nonzero(arr & int(lpt.ObjFlag.Ghost)))
n_repeated = int(np.count_nonzero(arr & int(lpt.ObjFlag.Repeated)))
print("ghost:", n_ghost, "repeated:", n_repeated)

score_list = shaker.score_list
ghost_score = [score_list[i] for i in cmp_st['ghost_indices']]
print(ghost_score)

# plot PDF of score list and ghost score
from matplotlib.ticker import MaxNLocator, FormatStrFormatter

scores = np.asarray(score_list, dtype=float)
print("mean of scores:", np.mean(scores))

print("minimum of ghost scores:", np.min(ghost_score))
gi = np.asarray(cmp_st['ghost_indices'])

# If ghost_indices is a boolean mask, convert to integer indices
if gi.dtype == bool:
    gi = np.flatnonzero(gi)

ghost_scores = scores[gi] if gi.size else np.array([])

# Freedman–Diaconis bins (robust, shared for both PDFs)
def fd_bins(x):
    x = x[np.isfinite(x)]
    if x.size < 2:
        return 10
    iqr = np.subtract(*np.percentile(x, [75, 25]))
    bw = 2 * iqr * (x.size ** (-1/3))
    if bw <= 0:
        return 10
    return max(10, int(np.ceil((x.max() - x.min()) / bw)))

bins = fd_bins(scores)
pdf_all, edges = np.histogram(scores, bins=bins, density=True)
centers = 0.5 * (edges[:-1] + edges[1:])

plt.figure()
plt.hist(scores,bins=edges, density=False, histtype='step', label=f'All (n={scores.size})')

if ghost_scores.size:
    plt.hist(ghost_scores, bins=edges, density=False, histtype='step', label=f'Ghost (n={ghost_scores.size})')

ax = plt.gca()
ax.set_yscale("log")
ax.xaxis.set_major_locator(MaxNLocator(nbins=8))
ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.xlabel('Score')
plt.ylabel('PDF')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# CameraType.PINHOLE
# ghost: 0 repeated: 0
# [0.027317051207972103, 0.030429630359757636, 0.030535167167058647]
# mean of scores: 0.027428750890486325
# minimum of ghost scores: 0.027317051207972103

# %%
# plot the position uncertianty after shaking
pts_shaked = np.array(
    [[obj._pt_center[0], obj._pt_center[1], obj._pt_center[2]] for obj in obj3d_list_shaked], 
    dtype=np.float32)
tol_mm = 1 * .04
cmp_shake = find_ghosts(pts_groundtrue, pts_shaked, tol_mm, use_ckdtree=True)

def clean_pos(x):
    x = np.asarray(x, float).ravel()
    return x[np.isfinite(x) & (x > 0.0)]  # log 轴不能有 <=0

d0 = clean_pos(cmp_st['dist_mm'])        # before shake
d1 = clean_pos(cmp_shake['dist_mm'])  # after  shake
if d0.size == 0 or d1.size == 0:
    print(f"Empty dist_mm: before={d0.size}, after={d1.size}")
else:
    # shared log-spaced bins on a robust range (1–99 percentile of both)
    all_pos = np.concatenate([d0, d1])
    lo = np.percentile(all_pos, 1)
    hi = np.percentile(all_pos, 99)
    lo = max(lo, np.min(all_pos))     # guard
    edges = np.logspace(np.log10(lo), np.log10(hi), 60)

    fig, ax = plt.subplots(figsize=(7, 3.8), dpi=150)
    ax.hist(d0, bins=edges, density=False, histtype='step', label=f'Before (n={d0.size})')
    ax.hist(d1, bins=edges, density=False, color = 'red', histtype='step', label=f'After  (n={d1.size})')

    ax.set_xscale('log')
    ax.set_xlabel('dist_mm (log scale)')
    ax.set_ylabel('PDF')

    # Reference lines: tolerance, medians, P90
    if 'tol_mm' in globals() and tol_mm and tol_mm > 0:
        ax.axvline(float(tol_mm), color='gray', ls='--', lw=1, label='tol')

    m0, m1 = np.median(d0), np.median(d1)
    p90_0, p90_1 = np.percentile(d0, 90), np.percentile(d1, 90)
    ax.axvline(m0,  ls='-',  lw=0.8, alpha=0.7)
    ax.axvline(m1,  ls='-',  color = 'red', lw=0.8, alpha=0.7)
    ax.axvline(p90_0, ls=':', lw=0.8, alpha=0.7)
    ax.axvline(p90_1, ls=':', color = 'red', lw=0.8, alpha=0.7)

    ax.legend()
    ax.grid(True, which='both', alpha=0.25)
    plt.tight_layout()
    plt.show()

    print(f"median:  before={m0:.3g} mm  ->  after={m1:.3g} mm  ({(m1/m0-1)*100:+.1f}%)")
    print(f"P90:     before={p90_0:.3g} mm ->  after={p90_1:.3g} mm ({(p90_1/p90_0-1)*100:+.1f}%)")
# Out:
# median:  before=0.0215 mm  ->  after=0.0222 mm  (+3.0%)
# P90:     before=0.0353 mm ->  after=0.0361 mm (+2.3%)

# %%
# test shake
real_obj_index = cmp_shake["matched_indices"]
obj_ind = real_obj_index[int(np.argmax(cmp_shake["dist_mm"][real_obj_index]))]
error_pos = cmp_shake["dist_mm"][obj_ind]
print("Worst-matched object index =", obj_ind, 
      "| reconstruction error distance (mm) =", error_pos)

pt_gt = pts_groundtrue[cmp_shake["rec_to_gt"][obj_ind]]
r_gt = r_groundtrue[cmp_shake["rec_to_gt"][obj_ind]]
obj_gt = lpt.Bubble3D(lpt.Pt3D(pt_gt[0], pt_gt[1], pt_gt[2]), r_gt)
obj_gt.projectObject2D(cam_list)

e_bf = cmp_st["dist_mm"][obj_ind]
e_af = cmp_shake["dist_mm"][obj_ind]
print("Error before Shake (mm) =", e_bf, 
      "| Error after Shake (mm) =", e_af)
obj_bf = obj3d_list[obj_ind]
obj_af = obj3d_list_shaked[obj_ind]
print("3D center before Shake =", obj_bf._pt_center,
      "| after Shake =", obj_af._pt_center,
      "| ground truth =", obj_gt._pt_center)

for obj in obj3d_list:
    obj.projectObject2D(cam_list)

with lpt.PythonStreamRedirector():
    shaker.calResidueImage(obj3d_list, image_list)

img_res_1 = np.array(shaker.img_res_list[0].to_list(), dtype=np.int16)
img_res_1[img_res_1 < 0] = 0
arr = np.array(img_res_1, dtype=np.uint8)

# 画出来
plt.imshow(arr, cmap="gray", origin="upper", vmin=0, vmax=255)
plt.colorbar()
plt.title("Resized Bubble")
plt.show()

roi_all = shaker.buildROIInfo(obj_bf, image_list)

n_cam = len(image_list)
cols = min(2, n_cam)
rows = int(np.ceil(n_cam / cols))
fig, axes = plt.subplots(rows, cols, figsize=(3.2*cols, 3.2*rows))

# 让 axes 索引安全（兼容 1x1 / 1xn / nx1）
def get_ax(axes, r, c):
    if rows == 1 and cols == 1:
        return axes
    elif rows == 1:
        return axes[c]
    elif cols == 1:
        return axes[r]
    else:
        return axes[r, c]

step = 1
gamma = 1.2  # alpha 映射幂次，>1 更突出高相关

resizer = lpt.BubbleResize()

for k in range(n_cam):
    ax = get_ax(axes, k // cols, k % cols)
    aug_img = roi_all[k].getAugImg()
    aug_img = np.array(aug_img.to_list(), dtype = np.uint8)
    ax.imshow(aug_img, cmap="gray", interpolation="nearest", origin="upper", vmin=0, vmax=255)
    ax.set_title(f"Cam {k}")
    ax.set_axis_off()

    roi = roi_all[k]
    rmin, rmax = roi.ROI_range.row_min, roi.ROI_range.row_max
    cmin, cmax = roi.ROI_range.col_min, roi.ROI_range.col_max
    # 画 before / after / GT 的 2D 点（坐标要减 ROI 偏移）
    x_bf = obj_bf._obj2d_list[k]._pt_center[0] 
    y_bf = obj_bf._obj2d_list[k]._pt_center[1]
    r_bf = obj_bf._obj2d_list[k]._r_px
    x_af = obj_af._obj2d_list[k]._pt_center[0]
    y_af = obj_af._obj2d_list[k]._pt_center[1] 
    r_af = obj_af._obj2d_list[k]._r_px
    x_gt = obj_gt._obj2d_list[k]._pt_center[0] 
    y_gt = obj_gt._obj2d_list[k]._pt_center[1]
    r_gt = obj_gt._obj2d_list[k]._r_px

    circ_bf = Circle((x_bf - cmin, y_bf - rmin), r_bf, fill=False, edgecolor="blue",  linewidth=1.2, label="before")
    circ_af = Circle((x_af - cmin, y_af - rmin), r_af, fill=False, edgecolor="red",   linewidth=1.2, label="after")
    circ_gt = Circle((x_gt - cmin, y_gt - rmin), r_gt, fill=False, edgecolor="green", linewidth=1.2, label="ground truth")

    ax.add_patch(circ_bf)
    ax.add_patch(circ_af)
    ax.add_patch(circ_gt)

    ax.plot(x_bf - cmin, y_bf - rmin, ".", color="blue",  ms=3)
    ax.plot(x_af - cmin, y_af - rmin, ".", color="red",   ms=3)
    ax.plot(x_gt - cmin, y_gt - rmin, ".", color="green", ms=3)

    d_k = int(obj_bf._obj2d_list[k]._r_px * 2 + 1)
    ref_k = resizer.ResizeBubble(bb_cfg._bb_ref_img[k], d_k, cam_list[k]._max_intensity)
    H, W = aug_img.shape[:2]
    corr_map = np.zeros((H, W), dtype=np.float32)
    rmin, rmax = roi.ROI_range.row_min, roi.ROI_range.row_max
    cmin, cmax = roi.ROI_range.col_min, roi.ROI_range.col_max

    for yy in range(0, H, step):
        gy = int(rmin + yy)        # 全图坐标 y
        for xx in range(0, W, step):
            gx = int(cmin + xx)    # 全图坐标 x
            v = shaker.strategy.getImgCorr(roi, gx, gy, ref_k)
            # 兼容返回类型：标量或含标量的对象
            val = float(v)
            corr_map[yy, xx] = val
    
    alpha = np.clip(corr_map, 0, 1) ** gamma
    im = ax.imshow(corr_map, cmap="rainbow", interpolation="nearest", origin="upper", alpha=alpha)
# Out:
# Worst-matched object index = 189 | reconstruction error distance (mm) = 0.03994786456949123
# Error before Shake (mm) = 0.02769890069006038 | Error after Shake (mm) = 0.03994786456949123
# 3D center before Shake = <Pt3D (9.587394,1.870494,18.944227)> | after Shake = <Pt3D (9.602393,1.897025,18.946727)> | ground truth = <Pt3D (9.611080,1.860040,18.934381)>

# %%
import pyopenlpt as lpt

config_file = '../../test/inputs/test_STB_Bubble/config_python.txt'
with lpt.PythonStreamRedirector():
    lpt.run(config_file)
# Out:
# **************
# OpenLPT start!
# **************
#
# Initial phase at frame 0
# START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 691  676  667  674   (0.46 s)
# 		Matched 309 objects. ( 2D tol: 2.00, t:0.01 s)	Obtained bubble reference image!	After shaking: 308 objects remain. (1.99 s)
# 	LOOP=0: TOTAL OBJECTS = 308
# 		2D detections per active camera: 382  417  407  410   (0.41 s)
# 		Matched 67 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 66 objects remain. (0.59 s)
# 	LOOP=1: TOTAL OBJECTS = 374
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 363  327  348   (0.40 s)
# 		Matched 76 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 74 objects remain. (0.53 s)
# 	LOOP=0: TOTAL OBJECTS = 448
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 295  340  277   (0.39 s)
# 		Matched 79 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 79 objects remain. (0.54 s)
# 	LOOP=0: TOTAL OBJECTS = 527
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 220  269  246   (0.36 s)
# 		Matched 72 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 71 objects remain. (0.53 s)
# 	LOOP=0: TOTAL OBJECTS = 598
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 179  199  196   (0.39 s)
# 		Matched 50 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 50 objects remain. (0.46 s)
# 	LOOP=0: TOTAL OBJECTS = 648
# IPR FINISH! FOUND 648 OBJECTS.
# Total time for frame 0: 7.14
#
# Initial phase at frame 1
# START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 691  666  670  676   (0.45 s)
# 		Matched 304 objects. ( 2D tol: 2.00, t:0.01 s)	After shaking: 303 objects remain. (1.98 s)
# 	LOOP=0: TOTAL OBJECTS = 303
# 		2D detections per active camera: 421  393  405  417   (0.45 s)
# 		Matched 75 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 73 objects remain. (0.63 s)
# 	LOOP=1: TOTAL OBJECTS = 376
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 358  330  359   (0.40 s)
# 		Matched 78 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 78 objects remain. (0.53 s)
# 	LOOP=0: TOTAL OBJECTS = 454
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 286  327  283   (0.37 s)
# 		Matched 72 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 71 objects remain. (0.51 s)
# 	LOOP=0: TOTAL OBJECTS = 525
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 216  259  252   (0.36 s)
# 		Matched 71 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 71 objects remain. (0.51 s)
# 	LOOP=0: TOTAL OBJECTS = 596
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 189  182  207   (0.35 s)
# 		Matched 46 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 45 objects remain. (0.41 s)
# 	LOOP=0: TOTAL OBJECTS = 641
# IPR FINISH! FOUND 641 OBJECTS.
# Total time for frame 1: 7.00
#
# Initial phase at frame 2
# START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 700  660  664  678   (0.45 s)
# 		Matched 303 objects. ( 2D tol: 2.00, t:0.01 s)	After shaking: 302 objects remain. (1.99 s)
# 	LOOP=0: TOTAL OBJECTS = 302
# 		2D detections per active camera: 427  390  385  419   (0.43 s)
# 		Matched 76 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 74 objects remain. (0.65 s)
# 	LOOP=1: TOTAL OBJECTS = 376
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 357  324  355   (0.41 s)
# 		Matched 86 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 84 objects remain. (0.56 s)
# 	LOOP=0: TOTAL OBJECTS = 460
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 284  312  275   (0.39 s)
# 		Matched 63 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 63 objects remain. (0.48 s)
# 	LOOP=0: TOTAL OBJECTS = 523
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 224  254  237   (0.38 s)
# 		Matched 69 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 69 objects remain. (0.50 s)
# 	LOOP=0: TOTAL OBJECTS = 592
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 189  168  204   (0.38 s)
# 		Matched 46 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 46 objects remain. (0.41 s)
# 	LOOP=0: TOTAL OBJECTS = 638
# IPR FINISH! FOUND 638 OBJECTS.
# Total time for frame 2: 7.07
#
# Initial phase at frame 3
# START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 694  661  675  673   (0.46 s)
# 		Matched 299 objects. ( 2D tol: 2.00, t:0.01 s)	After shaking: 298 objects remain. (1.93 s)
# 	LOOP=0: TOTAL OBJECTS = 298
# 		2D detections per active camera: 428  397  406  415   (0.43 s)
# 		Matched 73 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 71 objects remain. (0.61 s)
# 	LOOP=1: TOTAL OBJECTS = 369
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 332  351  364   (0.34 s)
# 		Matched 80 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 78 objects remain. (0.54 s)
# 	LOOP=0: TOTAL OBJECTS = 447
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 289  328  282   (0.40 s)
# 		Matched 71 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 71 objects remain. (0.51 s)
# 	LOOP=0: TOTAL OBJECTS = 518
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 222  262  253   (0.36 s)
# 		Matched 75 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 74 objects remain. (0.54 s)
# 	LOOP=0: TOTAL OBJECTS = 592
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 198  179  202   (0.37 s)
# 		Matched 55 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 55 objects remain. (0.45 s)
# 	LOOP=0: TOTAL OBJECTS = 647
# IPR FINISH! FOUND 647 OBJECTS.
#
# STB initial phase tracking b/w frames: 0 & 1;
# Linked tracks (0.00 s)
# STB initial phase tracking b/w frames: 1 & 2;
# 	Calculated predictive field (0.05 s), Linked tracks (0.00 s)
# STB initial phase tracking b/w frames: 2 & 3;
# 	Calculated predictive field (0.05 s), Linked tracks (0.00 s)
# STB initial phase tracking b/w frames: 3 & 4;
# 	Calculated predictive field (0.04 s), Linked tracks (0.00 s)
# Done with initial phase!
# ACTIVE SHORT TRACKS: 111; ACTIVE LONG TRACKS: 537; EXIT TRACKS: 0
#   Saved all tracks to folder: ../../test/results/test_STB_Bubble/InitialTrack/
# Total time for frame 3: 7.78
#
# Convergence phase at frame 4
#  Prediction: 0.00 s. Done!
#  Shake prediction: 3.22 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 235  219  227  243   (0.41 s)
# 		Matched 18 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 17 objects remain. (0.24 s)
# 	LOOP=0: TOTAL OBJECTS = 17
# 		2D detections per active camera: 218  204  212  227   (0.41 s)
# 		Matched 11 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 10 objects remain. (0.15 s)
# 	LOOP=1: TOTAL OBJECTS = 27
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 194  209  217   (0.36 s)
# 		Matched 33 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 32 objects remain. (0.35 s)
# 	LOOP=0: TOTAL OBJECTS = 59
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 181  197  187   (0.38 s)
# 		Matched 30 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 30 objects remain. (0.34 s)
# 	LOOP=0: TOTAL OBJECTS = 89
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 154  162  166   (0.35 s)
# 		Matched 20 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 20 objects remain. (0.25 s)
# 	LOOP=0: TOTAL OBJECTS = 109
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 140  146  159   (0.38 s)
# 		Matched 26 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 26 objects remain. (0.32 s)
# 	LOOP=0: TOTAL OBJECTS = 135
# IPR FINISH! FOUND 135 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 111 + 55 - 56 = 110
# 	No. of active long tracks: 537 + 25 - 7 = 555
# 	No. of exited long tracks: 0 + 0 = 0
# 	No. of exited short tracks(deleted): 1
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 4
# 	No. of fail linear fit: 2
# Total time for frame 4: 7.24
#
# Convergence phase at frame 5
#  Prediction: 0.00 s. Done!
#  Shake prediction: 3.31 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 229  220  208  206   (0.40 s)
# 		Matched 15 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 15 objects remain. (0.21 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# 		2D detections per active camera: 216  193  203  192   (0.40 s)
# 		Matched 11 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 10 objects remain. (0.16 s)
# 	LOOP=1: TOTAL OBJECTS = 25
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 209  201  183   (0.36 s)
# 		Matched 26 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 26 objects remain. (0.32 s)
# 	LOOP=0: TOTAL OBJECTS = 51
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 184  182  177   (0.36 s)
# 		Matched 21 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 20 objects remain. (0.26 s)
# 	LOOP=0: TOTAL OBJECTS = 71
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 165  165  160   (0.36 s)
# 		Matched 20 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 20 objects remain. (0.25 s)
# 	LOOP=0: TOTAL OBJECTS = 91
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 145  141  154   (0.36 s)
# 		Matched 26 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 26 objects remain. (0.33 s)
# 	LOOP=0: TOTAL OBJECTS = 117
# IPR FINISH! FOUND 117 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 110 + 32 - 47 = 95
# 	No. of active long tracks: 555 + 22 - 2 = 575
# 	No. of exited long tracks: 0 + 0 = 0
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 5: 7.13
#
# Convergence phase at frame 6
#  Prediction: 0.00 s. Done!
#  Shake prediction: 3.34 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 204  195  196  207   (0.45 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# 		2D detections per active camera: 190  180  184  195   (0.44 s)
# 		Matched 6 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=1: TOTAL OBJECTS = 19
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 185  178  189   (0.40 s)
# 		Matched 25 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 25 objects remain. (0.32 s)
# 	LOOP=0: TOTAL OBJECTS = 44
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 165  169  164   (0.37 s)
# 		Matched 16 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 16 objects remain. (0.20 s)
# 	LOOP=0: TOTAL OBJECTS = 60
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 149  154  154   (0.35 s)
# 		Matched 20 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 20 objects remain. (0.25 s)
# 	LOOP=0: TOTAL OBJECTS = 80
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 134  134  142   (0.40 s)
# 		Matched 25 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 25 objects remain. (0.34 s)
# 	LOOP=0: TOTAL OBJECTS = 105
# IPR FINISH! FOUND 105 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 95 + 31 - 43 = 83
# 	No. of active long tracks: 575 + 22 - 1 = 596
# 	No. of exited long tracks: 0 + 0 = 0
# 	No. of exited short tracks(deleted): 1
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 0
# Total time for frame 6: 7.20
#
# Convergence phase at frame 7
#  Prediction: 0.00 s. Done!
#  Shake prediction: 3.50 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 193  186  192  197   (0.43 s)
# 		Matched 18 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 18 objects remain. (0.24 s)
# 	LOOP=0: TOTAL OBJECTS = 18
# 		2D detections per active camera: 177  169  172  178   (0.42 s)
# 		Matched 12 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 12 objects remain. (0.17 s)
# 	LOOP=1: TOTAL OBJECTS = 30
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 168  159  166   (0.38 s)
# 		Matched 15 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 15 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 45
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 154  159  151   (0.38 s)
# 		Matched 15 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 58
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 142  144  148   (0.36 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 71
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 131  134  139   (0.39 s)
# 		Matched 17 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 17 objects remain. (0.21 s)
# 	LOOP=0: TOTAL OBJECTS = 88
# IPR FINISH! FOUND 88 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 83 + 27 - 50 = 60
# 	No. of active long tracks: 596 + 28 - 2 = 622
# 	No. of exited long tracks: 0 + 1 = 1
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 7: 7.07
#
# Convergence phase at frame 8
#  Prediction: 0.00 s. Done!
#  Shake prediction: 3.68 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 181  157  166  178   (0.41 s)
# 		Matched 14 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 14 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# 		2D detections per active camera: 170  142  154  163   (0.44 s)
# 		Matched 7 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 6 objects remain. (0.11 s)
# 	LOOP=1: TOTAL OBJECTS = 20
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 164  137  156   (0.37 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 30
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 156  148  145   (0.39 s)
# 		Matched 19 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 18 objects remain. (0.24 s)
# 	LOOP=0: TOTAL OBJECTS = 48
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 129  138  127   (0.35 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 61
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 114  114  123   (0.38 s)
# 		Matched 16 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 16 objects remain. (0.19 s)
# 	LOOP=0: TOTAL OBJECTS = 77
# IPR FINISH! FOUND 77 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 60 + 30 - 27 = 63
# 	No. of active long tracks: 622 + 14 - 1 = 635
# 	No. of exited long tracks: 1 + 1 = 2
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 0
# Total time for frame 8: 7.12
#
# Convergence phase at frame 9
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.04 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 163  156  147  162   (0.47 s)
# 		Matched 16 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 16 objects remain. (0.25 s)
# 	LOOP=0: TOTAL OBJECTS = 16
# 		2D detections per active camera: 148  140  131  145   (0.48 s)
# 		Matched 6 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=1: TOTAL OBJECTS = 21
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 146  126  141   (0.39 s)
# 		Matched 16 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 16 objects remain. (0.20 s)
# 	LOOP=0: TOTAL OBJECTS = 37
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 133  131  126   (0.38 s)
# 		Matched 15 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 15 objects remain. (0.20 s)
# 	LOOP=0: TOTAL OBJECTS = 52
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 119  108  118   (0.40 s)
# 		Matched 11 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 11 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 63
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 98  108  109   (0.38 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 73
# IPR FINISH! FOUND 73 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 63 + 17 - 18 = 62
# 	No. of active long tracks: 635 + 11 - 0 = 646
# 	No. of exited long tracks: 2 + 0 = 2
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 0 + 0 = 0
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 0
# Total time for frame 9: 7.65
#
# Convergence phase at frame 10
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.01 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 150  160  149  165   (0.44 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 10
# 		2D detections per active camera: 139  150  139  154   (0.48 s)
# 		Matched 8 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 8 objects remain. (0.18 s)
# 	LOOP=1: TOTAL OBJECTS = 18
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 144  148  131   (0.45 s)
# 		Matched 16 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 14 objects remain. (0.21 s)
# 	LOOP=0: TOTAL OBJECTS = 32
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 133  127  135   (0.41 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 45
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 120  118  116   (0.39 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.21 s)
# 	LOOP=0: TOTAL OBJECTS = 57
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 106  105  121   (0.44 s)
# 		Matched 11 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 67
# IPR FINISH! FOUND 67 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
#  VSC Accumulate: 0 points (0.55 s)
# 	No. of active short tracks: 62 + 14 - 28 = 48
# 	No. of active long tracks: 646 + 19 - 5 = 660
# 	No. of exited long tracks: 2 + 1 = 3
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 0 + 2 = 2
# 	No. of fail shaking intensity/repeated: 4
# 	No. of fail linear fit: 0
# Total time for frame 10: 8.33
#
# Convergence phase at frame 11
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.46 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 139  137  128  145   (0.45 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 6
# 		2D detections per active camera: 132  122  133  139   (0.47 s)
# 		Matched 3 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 9
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 130  119  136   (0.43 s)
# 		Matched 11 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 11 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 20
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 128  121  127   (0.41 s)
# 		Matched 14 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 14 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 34
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 109  115  103   (0.36 s)
# 		Matched 14 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 14 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 48
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 102  89  115   (0.42 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 55
# IPR FINISH! FOUND 55 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 48 + 18 - 29 = 37
# 	No. of active long tracks: 660 + 18 - 2 = 676
# 	No. of exited long tracks: 3 + 1 = 4
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 2 + 0 = 2
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 11: 7.84
#
# Convergence phase at frame 12
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.26 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 127  134  124  132   (0.45 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 2
# 		2D detections per active camera: 125  133  122  129   (0.50 s)
# 		Matched 5 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 5 objects remain. (0.09 s)
# 	LOOP=1: TOTAL OBJECTS = 7
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 116  129  124   (0.41 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 117  118  113   (0.50 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.21 s)
# 	LOOP=0: TOTAL OBJECTS = 32
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 104  97  102   (0.49 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 40
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 98  89  104   (0.40 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 44
# IPR FINISH! FOUND 44 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 37 + 16 - 19 = 34
# 	No. of active long tracks: 676 + 10 - 2 = 684
# 	No. of exited long tracks: 4 + 0 = 4
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 2 + 2 = 4
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 12: 7.80
#
# Convergence phase at frame 13
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.20 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 115  135  126  126   (0.48 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 130  111  122  123   (0.59 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 6
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 109  120  120   (0.44 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.17 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 126  108  108   (0.47 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.17 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 91  115  96   (0.39 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 37
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 85  109  100   (0.45 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 42
# IPR FINISH! FOUND 42 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 34 + 16 - 13 = 37
# 	No. of active long tracks: 684 + 5 - 3 = 686
# 	No. of exited long tracks: 4 + 1 = 5
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 4 + 1 = 5
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 1
# Total time for frame 13: 7.80
#
# Convergence phase at frame 14
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.05 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 130  116  130  129   (0.63 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.23 s)
# 	LOOP=0: TOTAL OBJECTS = 7
# 		2D detections per active camera: 123  109  124  120   (0.57 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 3 objects remain. (0.11 s)
# 	LOOP=1: TOTAL OBJECTS = 10
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 106  121  117   (0.59 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.20 s)
# 	LOOP=0: TOTAL OBJECTS = 20
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 110  115  107   (0.51 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 30
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 100  93  104   (0.40 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 37
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 85  97  95   (0.47 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 44
# IPR FINISH! FOUND 44 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 37 + 20 - 23 = 34
# 	No. of active long tracks: 686 + 10 - 4 = 692
# 	No. of exited long tracks: 5 + 3 = 8
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 5 + 1 = 6
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 14: 9.23
#
# Convergence phase at frame 15
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.51 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 107  129  119  122   (0.42 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.15 s)
# 	LOOP=0: TOTAL OBJECTS = 9
# 		2D detections per active camera: 97  121  110  113   (0.44 s)
# 		Matched 3 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 11
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 95  109  112   (0.41 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 116  101  107   (0.41 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.13 s)
# 	LOOP=0: TOTAL OBJECTS = 28
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 85  93  108   (0.35 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 37
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 76  100  97   (0.41 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 44
# IPR FINISH! FOUND 44 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 34 + 16 - 14 = 36
# 	No. of active long tracks: 692 + 8 - 1 = 699
# 	No. of exited long tracks: 8 + 0 = 8
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 6 + 0 = 6
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 15: 7.75
#
# Convergence phase at frame 16
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.13 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 123  108  125  120   (0.41 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 5
# 		2D detections per active camera: 103  118  115  119   (0.40 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 7
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 101  118  117   (0.36 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 17
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 108  109  110   (0.38 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.13 s)
# 	LOOP=0: TOTAL OBJECTS = 27
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 97  89  100   (0.38 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 33
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 85  100  94   (0.39 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 39
# IPR FINISH! FOUND 39 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 36 + 14 - 16 = 34
# 	No. of active long tracks: 699 + 5 - 4 = 700
# 	No. of exited long tracks: 8 + 3 = 11
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 6 + 0 = 6
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 16: 7.16
#
# Convergence phase at frame 17
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.04 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 126  111  126  120   (0.41 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 5
# 		2D detections per active camera: 106  119  121  115   (0.39 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=1: TOTAL OBJECTS = 9
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 103  117  112   (0.37 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 16
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 111  114  104   (0.36 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 29
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 94  101  98   (0.34 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 41
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 90  83  91   (0.36 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.17 s)
# 	LOOP=0: TOTAL OBJECTS = 53
# IPR FINISH! FOUND 53 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 34 + 25 - 18 = 41
# 	No. of active long tracks: 700 + 12 - 1 = 711
# 	No. of exited long tracks: 11 + 0 = 11
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 6 + 0 = 6
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 17: 7.11
#
# Convergence phase at frame 18
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.07 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 114  114  104  115   (0.39 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 110  100  111  110   (0.39 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=1: TOTAL OBJECTS = 8
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 106  95  106   (0.37 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 101  106  101   (0.37 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.13 s)
# 	LOOP=0: TOTAL OBJECTS = 23
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 97  90  88   (0.36 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 32
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 88  79  90   (0.40 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.17 s)
# 	LOOP=0: TOTAL OBJECTS = 44
# IPR FINISH! FOUND 44 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 41 + 10 - 13 = 38
# 	No. of active long tracks: 711 + 6 - 2 = 715
# 	No. of exited long tracks: 11 + 0 = 11
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 6 + 2 = 8
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 18: 7.07
#
# Convergence phase at frame 19
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.29 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 106  111  118  116   (0.41 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 7
# 		2D detections per active camera: 106  99  112  106   (0.42 s)
# 		Matched 5 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 5 objects remain. (0.11 s)
# 	LOOP=1: TOTAL OBJECTS = 12
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 95  100  107   (0.45 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 17
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 95  98  102   (0.43 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 25
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 87  88  90   (0.42 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 33
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 81  94  84   (0.41 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 41
# IPR FINISH! FOUND 41 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 38 + 11 - 17 = 32
# 	No. of active long tracks: 715 + 9 - 5 = 719
# 	No. of exited long tracks: 11 + 3 = 14
# 	No. of exited short tracks(deleted): 1
# 	No. of inactive Long tracks: 8 + 1 = 9
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 19: 7.56
#
# Convergence phase at frame 20
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.25 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 110  107  109  110   (0.49 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 8
# 		2D detections per active camera: 102  99  101  101   (0.46 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 10
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 96  100  99   (0.39 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 95  99  94   (0.42 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 23
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 87  91  88   (0.35 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 8 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 84  80  86   (0.43 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 40
# IPR FINISH! FOUND 40 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
#  VSC Accumulate: 0 points (0.48 s)
# 	No. of active short tracks: 32 + 13 - 18 = 27
# 	No. of active long tracks: 719 + 13 - 3 = 729
# 	No. of exited long tracks: 14 + 3 = 17
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 9 + 0 = 9
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 0
# Total time for frame 20: 7.99
#
# Convergence phase at frame 21
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.67 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 98  99  100  107   (0.41 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 93  95  96  103   (0.56 s)
# 		Matched 0 objects. ( 2D tol: 3.00, t:0.00 s)
# 	LOOP=1: TOTAL OBJECTS = 4
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 93  96  103   (0.47 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.16 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 93  88  96   (0.47 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.15 s)
# 	LOOP=0: TOTAL OBJECTS = 22
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 79  85  87   (0.56 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 70  76  78   (0.42 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 35
# IPR FINISH! FOUND 35 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 27 + 20 - 17 = 30
# 	No. of active long tracks: 729 + 5 - 4 = 730
# 	No. of exited long tracks: 17 + 2 = 19
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 9 + 2 = 11
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 21: 8.24
#
# Convergence phase at frame 22
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.94 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 95  101  92  101   (0.53 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 2
# 		2D detections per active camera: 93  90  99  99   (0.50 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 4
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 88  97  97   (0.51 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.15 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 91  88  88   (0.46 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 12 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 26
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 80  76  76   (0.39 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 72  75  75   (0.43 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 35
# IPR FINISH! FOUND 35 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 30 + 15 - 15 = 30
# 	No. of active long tracks: 730 + 5 - 2 = 733
# 	No. of exited long tracks: 19 + 1 = 20
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 11 + 1 = 12
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 22: 9.48
#
# Convergence phase at frame 23
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.03 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 95  92  102  104   (0.48 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 98  91  88  100   (0.56 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 6
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 86  96  98   (0.42 s)
# 		Matched 13 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 13 objects remain. (0.17 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 89  85  86   (0.38 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.13 s)
# 	LOOP=0: TOTAL OBJECTS = 29
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 79  71  77   (0.37 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 33
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 67  75  77   (0.40 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 38
# IPR FINISH! FOUND 38 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 30 + 12 - 7 = 35
# 	No. of active long tracks: 733 + 3 - 2 = 734
# 	No. of exited long tracks: 20 + 0 = 20
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 12 + 2 = 14
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 23: 8.32
#
# Convergence phase at frame 24
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.48 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 97  90  108  99   (0.45 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 5
# 		2D detections per active camera: 92  84  103  95   (0.44 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=1: TOTAL OBJECTS = 9
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 80  90  98   (0.39 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 87  80  88   (0.39 s)
# 		Matched 9 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.13 s)
# 	LOOP=0: TOTAL OBJECTS = 28
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 79  69  71   (0.38 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 76  66  78   (0.38 s)
# 		Matched 8 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 38
# IPR FINISH! FOUND 38 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 35 + 9 - 14 = 30
# 	No. of active long tracks: 734 + 8 - 2 = 740
# 	No. of exited long tracks: 20 + 0 = 20
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 14 + 1 = 15
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 1
# Total time for frame 24: 7.62
#
# Convergence phase at frame 25
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.39 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 92  86  92  102   (0.41 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 3
# 		2D detections per active camera: 90  82  89  99   (0.43 s)
# 		Matched 1 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 0 objects remain. (0.05 s)
# 	LOOP=1: TOTAL OBJECTS = 3
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 82  89  99   (0.36 s)
# 		Matched 11 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 11 objects remain. (0.15 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 90  78  89   (0.38 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 10 objects remain. (0.14 s)
# 	LOOP=0: TOTAL OBJECTS = 24
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 72  80  70   (0.36 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 27
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 69  77  80   (0.37 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 33
# IPR FINISH! FOUND 33 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 30 + 11 - 17 = 24
# 	No. of active long tracks: 740 + 9 - 2 = 747
# 	No. of exited long tracks: 20 + 1 = 21
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 15 + 1 = 16
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 25: 7.35
#
# Convergence phase at frame 26
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.35 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 89  90  96  98   (0.44 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 5
# 		2D detections per active camera: 84  85  93  92   (0.47 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 3 objects remain. (0.09 s)
# 	LOOP=1: TOTAL OBJECTS = 8
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 81  90  89   (0.60 s)
# 		Matched 12 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 11 objects remain. (0.18 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 81  80  78   (0.45 s)
# 		Matched 10 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 9 objects remain. (0.15 s)
# 	LOOP=0: TOTAL OBJECTS = 28
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 67  73  69   (0.40 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 31
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 65  70  69   (0.38 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 37
# IPR FINISH! FOUND 37 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 24 + 17 - 12 = 29
# 	No. of active long tracks: 747 + 8 - 2 = 753
# 	No. of exited long tracks: 21 + 0 = 21
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 16 + 2 = 18
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 26: 7.87
#
# Convergence phase at frame 27
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.31 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 80  91  87  92   (0.56 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 76  87  83  88   (0.57 s)
# 		Matched 5 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 4 objects remain. (0.10 s)
# 	LOOP=1: TOTAL OBJECTS = 8
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 71  83  84   (0.49 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 76  77  78   (0.49 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 21
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 70  65  72   (0.40 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 28
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 58  65  69   (0.46 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 34
# IPR FINISH! FOUND 34 OBJECTS.
#  Remove overlap: 0.00 s.
# ...
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 110 + 2 = 112
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 104: 8.04
#
# Convergence phase at frame 105
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.62 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 40  53  50  45   (0.46 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 3
# 		2D detections per active camera: 50  37  47  42   (0.45 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 5
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 48  44  40   (0.43 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 9
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 35  40  36   (0.46 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 10
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 34  43  39   (0.38 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 12
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 41  32  35   (0.46 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# IPR FINISH! FOUND 19 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 10 + 9 - 2 = 17
# 	No. of active long tracks: 817 + 2 - 4 = 815
# 	No. of exited long tracks: 127 + 1 = 128
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 112 + 3 = 115
# 	No. of fail shaking intensity/repeated: 3
# 	No. of fail linear fit: 0
# Total time for frame 105: 7.77
#
# Convergence phase at frame 106
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.93 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 36  57  54  45   (0.46 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 1
# 		2D detections per active camera: 53  56  35  44   (0.41 s)
# 		Matched 1 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 1 objects remain. (0.07 s)
# 	LOOP=1: TOTAL OBJECTS = 2
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 51  55  43   (0.41 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 8
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 45  33  37   (0.45 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 10
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 47  43  31   (0.38 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 12
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 46  29  35   (0.44 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 18
# IPR FINISH! FOUND 18 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 17 + 1 - 4 = 14
# 	No. of active long tracks: 815 + 4 - 4 = 815
# 	No. of exited long tracks: 128 + 1 = 129
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 115 + 3 = 118
# 	No. of fail shaking intensity/repeated: 3
# 	No. of fail linear fit: 0
# Total time for frame 106: 8.02
#
# Convergence phase at frame 107
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.39 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 44  50  45  58   (0.46 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 2
# 		2D detections per active camera: 42  48  56  43   (0.49 s)
# 		Matched 3 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 3 objects remain. (0.09 s)
# 	LOOP=1: TOTAL OBJECTS = 5
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 45  52  40   (0.42 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 10
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 38  47  35   (0.40 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 35  40  44   (0.41 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 16
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 37  32  31   (0.40 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# IPR FINISH! FOUND 19 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 14 + 6 - 6 = 14
# 	No. of active long tracks: 815 + 4 - 4 = 815
# 	No. of exited long tracks: 129 + 3 = 132
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 118 + 1 = 119
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 107: 8.53
#
# Convergence phase at frame 108
#  Prediction: 0.00 s. Done!
#  Shake prediction: 6.14 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 47  49  53  44   (0.49 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 43  45  49  40   (0.49 s)
# 		Matched 3 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 3 objects remain. (0.09 s)
# 	LOOP=1: TOTAL OBJECTS = 7
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 42  46  37   (0.44 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 39  40  31   (0.48 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 37  35  38   (0.40 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 18
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 32  35  28   (0.41 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# IPR FINISH! FOUND 19 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 14 + 7 - 9 = 12
# 	No. of active long tracks: 815 + 7 - 3 = 819
# 	No. of exited long tracks: 132 + 3 = 135
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 119 + 0 = 119
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 0
# Total time for frame 108: 9.37
#
# Convergence phase at frame 109
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.94 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 48  50  46  50   (0.51 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.12 s)
# 	LOOP=0: TOTAL OBJECTS = 6
# 		2D detections per active camera: 42  40  44  44   (0.49 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=1: TOTAL OBJECTS = 8
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 40  42  42   (0.43 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 11
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 39  37  39   (0.43 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 36  36  34   (0.36 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 17
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 31  33  35   (0.47 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.04 s)
# 	LOOP=0: TOTAL OBJECTS = 18
# IPR FINISH! FOUND 18 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 12 + 9 - 4 = 17
# 	No. of active long tracks: 819 + 1 - 4 = 816
# 	No. of exited long tracks: 135 + 3 = 138
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 119 + 1 = 120
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 109: 8.12
#
# Convergence phase at frame 110
#  Prediction: 0.00 s. Done!
#  Shake prediction: 5.92 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 44  57  51  47   (0.38 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 1
# 		2D detections per active camera: 50  43  56  46   (0.43 s)
# 		Matched 4 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=1: TOTAL OBJECTS = 5
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 52  42  46   (1.33 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 8
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 39  49  39   (0.46 s)
# 		Matched 7 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 7 objects remain. (0.11 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 39  42  32   (0.77 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 28  35  31   (0.46 s)
# 		Matched 0 objects. ( 2D tol: 2.00, t:0.00 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# IPR FINISH! FOUND 19 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
#   VSC Volume: 39.88 x 39.79 x 39.84 (LxWxH)
#  VSC Accumulate: 532 points (0.60 s)
# 	No. of active short tracks: 17 + 5 - 5 = 17
# 	No. of active long tracks: 816 + 2 - 2 = 816
# 	No. of exited long tracks: 138 + 1 = 139
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 120 + 1 = 121
# 	No. of fail shaking intensity/repeated: 1
# 	No. of fail linear fit: 0
# Total time for frame 110: 10.80
#
# Convergence phase at frame 111
#  Prediction: 0.00 s. Done!
#  Shake prediction: 6.74 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 54  45  52  44   (0.46 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 4
# 		2D detections per active camera: 41  50  48  40   (0.42 s)
# 		Matched 2 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=1: TOTAL OBJECTS = 6
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 48  46  38   (0.35 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 9
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 39  43  35   (0.37 s)
# 		Matched 5 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 5 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 43  34  38   (0.35 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.10 s)
# 	LOOP=0: TOTAL OBJECTS = 18
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 39  30  29   (0.42 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 19
# IPR FINISH! FOUND 19 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 17 + 3 - 6 = 14
# 	No. of active long tracks: 816 + 5 - 3 = 818
# 	No. of exited long tracks: 139 + 0 = 139
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 121 + 2 = 123
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 1
# Total time for frame 111: 9.64
#
# Convergence phase at frame 112
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.68 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 38  54  51  45   (0.43 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 2
# 		2D detections per active camera: 36  52  49  44   (0.43 s)
# 		Matched 1 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=1: TOTAL OBJECTS = 3
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 51  48  43   (0.41 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 4 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 7
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 35  43  39   (0.41 s)
# 		Matched 6 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 6 objects remain. (0.09 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 29  45  37   (0.38 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 14
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 28  43  35   (0.41 s)
# 		Matched 1 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 1 objects remain. (0.04 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# IPR FINISH! FOUND 15 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 14 + 5 - 8 = 11
# 	No. of active long tracks: 818 + 4 - 2 = 820
# 	No. of exited long tracks: 139 + 0 = 139
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 123 + 2 = 125
# 	No. of fail shaking intensity/repeated: 2
# 	No. of fail linear fit: 0
# Total time for frame 112: 7.57
#
# Convergence phase at frame 113
#  Prediction: 0.00 s. Done!
#  Shake prediction: 4.68 s.
#  START IPR...
# Full cameras
# Combination 0 cams=[0, 1, 2, 3]
# 		2D detections per active camera: 43  54  52  46   (0.41 s)
# 		Matched 3 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.08 s)
# 	LOOP=0: TOTAL OBJECTS = 3
# 		2D detections per active camera: 40  51  49  43   (0.41 s)
# 		Matched 5 objects. ( 2D tol: 3.00, t:0.00 s)	After shaking: 5 objects remain. (0.10 s)
# 	LOOP=1: TOTAL OBJECTS = 8
# Reduced cameras
# Combination 0 cams=[0, 1, 2]
# 		2D detections per active camera: 46  44  38   (0.37 s)
# 		Matched 4 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 3 objects remain. (0.07 s)
# 	LOOP=0: TOTAL OBJECTS = 11
# Combination 1 cams=[0, 1, 3]
# 		2D detections per active camera: 34  41  35   (0.36 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 13
# Combination 2 cams=[0, 2, 3]
# 		2D detections per active camera: 32  43  39   (0.33 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.06 s)
# 	LOOP=0: TOTAL OBJECTS = 15
# Combination 3 cams=[1, 2, 3]
# 		2D detections per active camera: 30  41  33   (0.36 s)
# 		Matched 2 objects. ( 2D tol: 2.00, t:0.00 s)	After shaking: 2 objects remain. (0.05 s)
# 	LOOP=0: TOTAL OBJECTS = 17
# IPR FINISH! FOUND 17 OBJECTS.
#  Remove overlap: 0.00 s.
#  Linking: 0.00 s. Done!
#  Pruning time: 0.00 s
# 	No. of active short tracks: 11 + 8 - 7 = 12
# 	No. of active long tracks: 820 + 5 - 3 = 822
# 	No. of exited long tracks: 139 + 2 = 141
# 	No. of exited short tracks(deleted): 0
# 	No. of inactive Long tracks: 125 + 1 = 126
# 	No. of fail shaking intensity/repeated: 0
# 	No. of fail linear fit: 1
# Total time for frame 113: 7.39
#
# Convergence phase at frame 114
#  Prediction: 0.00 s. Done!
